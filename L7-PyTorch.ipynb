# %% [markdown]
# # Leap of Faith in PyTorch [L7] - Code on Our Reading (Day 7) - Demo
#
# ## 👉 [check it on Medium - Leap of Faith in PyTorch [L7] -  (Day 7)]()

# %% [markdown]
# ### Step 1:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ["Reading Books", "Phone Usage"]
time_spent = [17, 5.4 * 60]  # Convert hours to minutes

# Plot
plt.figure(figsize=(6, 5))
plt.bar(categories, time_spent, color=['blue', 'red'])
plt.ylabel("Minutes per Day")
plt.title("Daily Time Spent: Reading vs. Phone Usage")
plt.show()

# %% [markdown]
# ### Step 2:

# %%
# Data
years = np.arange(2004, 2018, 1)
men_reading = [100 - (40 * (y - 2004) / 13) for y in years]  # Simulating 40% decline
women_reading = [100 - (29 * (y - 2004) / 13) for y in years]  # Simulating 29% decline

# Plot
plt.figure(figsize=(7, 5))
plt.plot(years, men_reading, label="Men", marker='o', linestyle='-', color='blue')
plt.plot(years, women_reading, label="Women", marker='o', linestyle='-.', color='red')
plt.xlabel("Year")
plt.ylabel("Percentage of Population Reading for Pleasure")
plt.title("Decline in Reading for Pleasure (2004-2017)")
plt.legend()
plt.show()

# %% [markdown]
# ### Step 3:

# %%
# Data
labels = ["Non-Readers", "Readers"]
sizes = [57, 43]  # 57% non-readers, 43% readers
colors = ['red', 'green']

# Plot
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors, startangle=90)
plt.title("Percentage of Americans Who Did Not Read a Book in 2017")
plt.show()

# %%
# Data
years = [2008, 2011, 2016]
market_shrink = [100, 100 - 26, 60]  # 40% decline by 2016

# Plot
plt.figure(figsize=(7, 5))
plt.bar(years, market_shrink, color='purple', width=1.5)
plt.xlabel("Year")
plt.ylabel("Percentage of Market Remaining")
plt.title("Decline in the Novel Market (2008-2016)")
plt.show()

# %%
import torch
import matplotlib.pyplot as plt

# 1. Daily Reading vs Phone Usage (Bar Chart)
def plot_reading_vs_phone():
    categories = ["Reading Books", "Phone Usage"]
    time_spent = torch.tensor([17, 5.4 * 60])  # Convert hours to minutes

    plt.figure(figsize=(6, 5))
    plt.bar(categories, time_spent.numpy(), color=['blue', 'red'])
    plt.ylabel("Minutes per Day")
    plt.title("Daily Time Spent: Reading vs. Phone Usage")
    plt.show()

# 2. Decline in Reading for Pleasure (Line Chart)
def plot_decline_reading():
    years = torch.arange(2004, 2018, 1)
    men_reading = 100 - (40 * (years - 2004) / 13)
    women_reading = 100 - (29 * (years - 2004) / 13)

    plt.figure(figsize=(7, 5))
    plt.plot(years.numpy(), men_reading.numpy(), label="Men", marker='o', linestyle='-', color='blue')
    plt.plot(years.numpy(), women_reading.numpy(), label="Women", marker='o', linestyle='-.', color='red')
    plt.xlabel("Year")
    plt.ylabel("Percentage of Population Reading for Pleasure")
    plt.title("Decline in Reading for Pleasure (2004-2017)")
    plt.legend()
    plt.show()

# 3. Percentage of Non-Readers (Pie Chart)
def plot_non_readers():
    labels = ["Non-Readers", "Readers"]
    sizes = torch.tensor([57, 43])  # 57% non-readers, 43% readers
    colors = ['red', 'green']

    plt.figure(figsize=(6, 6))
    plt.pie(sizes.numpy(), labels=labels, autopct='%1.1f%%', colors=colors, startangle=90)
    plt.title("Percentage of Americans Who Did Not Read a Book in 2017")
    plt.show()

# 4. Shrinking Novel Market (Bar Chart)
def plot_novel_market():
    years = torch.tensor([2008, 2011, 2016])
    market_shrink = torch.tensor([100, 100 - 26, 60])  # 40% decline by 2016

    plt.figure(figsize=(7, 5))
    plt.bar(years.numpy(), market_shrink.numpy(), color='purple', width=1.5)
    plt.xlabel("Year")
    plt.ylabel("Percentage of Market Remaining")
    plt.title("Decline in the Novel Market (2008-2016)")
    plt.show()

# Execute all plots
plot_reading_vs_phone()
plot_decline_reading()
plot_non_readers()
plot_novel_market()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def convert_to_excalibur_style_from_array(image_array):
    """
    Converts an image array to a black-and-white sketch style similar to Excalibur drawing tool.

    Parameters:
    - image_array (numpy.ndarray): Input image array.

    Returns:
    - sketch_image: The processed image in Excalibur-like style.
    """
    # Ensure image is grayscale
    if len(image_array.shape) == 3:  # If RGB, convert to grayscale
        image_array = cv2.cvtColor(image_array, cv2.COLOR_RGBA2GRAY)

    # Invert the image
    inverted_image = 255 - image_array

    # Apply Gaussian Blur
    blurred_image = cv2.GaussianBlur(inverted_image, (21, 21), 0)

    # Create sketch effect
    sketch_image = cv2.divide(image_array, 255 - blurred_image, scale=256)

    # Display the processed image
    plt.figure(figsize=(10, 8))
    plt.imshow(sketch_image, cmap="gray")
    plt.axis("off")  # Keep axes visible
    plt.title("Excalibur-Style Black & White Sketch")
    plt.show()

    return sketch_image

def capture_image_from_plot():
    """
    Captures the currently displayed Matplotlib figure as an image array while keeping the axes.
    """
    # Create a figure and axes
    fig, ax = plt.subplots(figsize=(6, 6))
    
    # Example plot (with axes)
    x = np.linspace(0, 10, 100)
    y = np.sin(x)
    ax.plot(x, y, color='black', linewidth=2)
    ax.set_xlabel("X-axis Label")  # Keep axis labels
    ax.set_ylabel("Y-axis Label")
    ax.set_title("Original Plot with Axes")

    fig.canvas.draw()

    # Convert figure to an image array (RGBA format)
    img_array = np.array(fig.canvas.renderer.buffer_rgba())

    # Close the figure to free memory
    plt.close(fig)

    return img_array

# Capture the image from the plot (with axes)
image_from_plot = capture_image_from_plot()

# Convert to Excalibur-style sketch while keeping axes
convert_to_excalibur_style_from_array(image_from_plot)
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
# 4. Shrinking Novel Market (Bar Chart)
import cv2
import numpy as np
import matplotlib.pyplot as plt


plt.rcParams.update({
    'axes.titlesize': 22,      # Title font size
    'axes.labelsize': 20,      # X and Y label font size
    'xtick.labelsize': 18,     # X-axis tick font size
    'ytick.labelsize': 18,     # Y-axis tick font size
    'legend.fontsize': 18,     # Legend font size
    'figure.titlesize': 24     # Figure title font size
})


def convert_to_excalibur_style_from_array(image_array, figh, figw):
    """
    Converts an image array to a black-and-white sketch style similar to Excalibur drawing tool.

    Parameters:
    - image_array (numpy.ndarray): Input image array.

    Returns:
    - sketch_image: The processed image in Excalibur-like style.
    """
    # Ensure image is grayscale
    if len(image_array.shape) == 3:  # If RGB, convert to grayscale
        image_array = cv2.cvtColor(image_array, cv2.COLOR_RGBA2GRAY)

    # Invert the image
    inverted_image = 255 - image_array

    # Apply Gaussian Blur
    blurred_image = cv2.GaussianBlur(inverted_image, (21, 21), 0)

    # Create sketch effect
    sketch_image = cv2.divide(image_array, 255 - blurred_image, scale=256)

    # Display the processed image
    plt.figure(figsize=(figh, figw))
    plt.imshow(sketch_image, cmap="gray")
    plt.axis("off")  # Keep axes visible
    plt.title("Excalibur-Style Black & White Sketch")
    plt.show()

    return sketch_image

def plot_novel_market(figh, figw):
    years = torch.tensor([2008, 2011, 2016])
    market_shrink = torch.tensor([100, 100 - 26, 60])  # 40% decline by 2016

    fig, ax = plt.subplots(figsize=(figh, figh))
    ax.bar(years.numpy(), market_shrink.numpy(), color='purple', width=1.5)
    ax.set_xlabel("Year")
    ax.set_ylabel("Percentage of Market Remaining")
    ax.set_title("Decline in the Novel Market (2008-2016)")

    fig.canvas.draw()

    # Convert figure to an image array (RGBA format)
    img_array = np.array(fig.canvas.renderer.buffer_rgba())

    # Close the figure to free memory
    plt.close(fig)

    return img_array


figh, figw = 14, 12
# Capture the image from the plot (with axes)
image_from_plot = plot_novel_market(figh, figw)

# Convert to Excalibur-style sketch while keeping axes
convert_to_excalibur_style_from_array(image_from_plot, figh, figw)
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
import torch
import matplotlib.pyplot as plt

# 1. Daily Reading vs Phone Usage (Bar Chart)
def plot_reading_vs_phone(figh, figw):
    categories = ["Reading Books", "Phone Usage"]
    time_spent = torch.tensor([17, 5.4 * 60])  # Convert hours to minutes

    fig, ax = plt.subplots(figsize=(figh, figw))    
    ax.bar(categories, time_spent.numpy(), color=['blue', 'red'])
    ax.set_ylabel("Minutes per Day")
    ax.set_title("Daily Time Spent: Reading vs. Phone Usage")
    fig.canvas.draw()

    # Convert figure to an image array (RGBA format)
    img_array = np.array(fig.canvas.renderer.buffer_rgba())

    # Close the figure to free memory
    plt.close(fig)

    return img_array

# 2. Decline in Reading for Pleasure (Line Chart)
def plot_decline_reading(figh, figw):
    years = torch.arange(2004, 2018, 1)
    men_reading = 100 - (40 * (years - 2004) / 13)
    women_reading = 100 - (29 * (years - 2004) / 13)

    fig, ax = plt.subplots(figsize=(figh, figw))
    ax.plot(years.numpy(), men_reading.numpy(), label="Men", marker='o', linestyle='-', color='blue')
    ax.plot(years.numpy(), women_reading.numpy(), label="Women", marker='o', linestyle='-.', color='red')
    ax.set_xlabel("Year")
    ax.set_ylabel("Percentage of Population Reading for Pleasure")
    ax.set_title("Decline in Reading for Pleasure (2004-2017)")
    ax.legend()
    fig.canvas.draw()

    # Convert figure to an image array (RGBA format)
    img_array = np.array(fig.canvas.renderer.buffer_rgba())

    # Close the figure to free memory
    plt.close(fig)

    return img_array

# 3. Percentage of Non-Readers (Pie Chart)
def plot_non_readers(figh, figw):
    labels = ["Non-Readers", "Readers"]
    sizes = torch.tensor([57, 43])  # 57% non-readers, 43% readers
    colors = ['red', 'green']

    fig, ax = plt.subplots(figsize=(figh, figw))
    ax.pie(
        sizes.numpy(), labels=labels, autopct='%1.1f%%', colors=colors, startangle=90,
        wedgeprops={'edgecolor': 'black', 'linewidth': 2}  # Add black borders
    )
    ax.set_title("Percentage of Americans Who Did Not Read a Book in 2017")
    fig.canvas.draw()

    # Convert figure to an image array (RGBA format)
    img_array = np.array(fig.canvas.renderer.buffer_rgba())

    # Close the figure to free memory
    plt.close(fig)

    return img_array


# 4. Shrinking Novel Market (Bar Chart)
def plot_novel_market(figh, figw):
    years = torch.tensor([2008, 2011, 2016])
    market_shrink = torch.tensor([100, 100 - 26, 60])  # 40% decline by 2016

    fig, ax = plt.subplots(figsize=(figh, figw))
    ax.bar(years.numpy(), market_shrink.numpy(), color='purple', width=3.5)
    ax.set_xlabel("Year")
    ax.set_ylabel("Percentage of Market Remaining")
    ax.set_title("Decline in the Novel Market (2008-2016)")

    fig.canvas.draw()

    # Convert figure to an image array (RGBA format)
    img_array = np.array(fig.canvas.renderer.buffer_rgba())

    # Close the figure to free memory
    plt.close(fig)

    return img_array


def convert_to_excalibur_style_from_array(image_array, figh, figw):
    """
    Converts an image array to a black-and-white sketch style similar to Excalibur drawing tool.

    Parameters:
    - image_array (numpy.ndarray): Input image array.

    Returns:
    - sketch_image: The processed image in Excalibur-like style.
    """
    # Ensure image is grayscale
    if len(image_array.shape) == 3:  # If RGB, convert to grayscale
        image_array = cv2.cvtColor(image_array, cv2.COLOR_RGBA2GRAY)

    # Invert the image
    inverted_image = 255 - image_array

    # Apply Gaussian Blur
    blurred_image = cv2.GaussianBlur(inverted_image, (21, 21), 0)

    # Create sketch effect
    sketch_image = cv2.divide(image_array, 255 - blurred_image, scale=256)

    # Display the processed image
    plt.figure(figsize=(figh, figw))
    plt.imshow(sketch_image, cmap="gray")
    plt.axis("off")  # Keep axes visible
    plt.title("Excalibur-Style Black & White Sketch")
    plt.show()

    return sketch_image


figh, figw = 14, 12
# Capture the image from the plot (with axes)
image_from_plot = plot_reading_vs_phone(figh, figw)

# Convert to Excalibur-style sketch while keeping axes
convert_to_excalibur_style_from_array(image_from_plot, figh, figw)



figh, figw = 14, 12
# Capture the image from the plot (with axes)
image_from_plot = plot_decline_reading(figh, figw)

# Convert to Excalibur-style sketch while keeping axes
convert_to_excalibur_style_from_array(image_from_plot, figh, figw)



figh, figw = 14, 12
# Capture the image from the plot (with axes)
image_from_plot = plot_non_readers(figh, figw)

# Convert to Excalibur-style sketch while keeping axes
convert_to_excalibur_style_from_array(image_from_plot, figh, figw)



figh, figw = 14, 12
# Capture the image from the plot (with axes)
image_from_plot = plot_novel_market(figh, figw)

# Convert to Excalibur-style sketch while keeping axes
convert_to_excalibur_style_from_array(image_from_plot, figh, figw)
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)
